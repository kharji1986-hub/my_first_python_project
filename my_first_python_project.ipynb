# %% [markdown]
# <a href="https://colab.research.google.com/github/kharji1986-hub/my_first_python_project/blob/main/my_first_python_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("what is your name?")
age = input("how old are you?")
print("hello", name)
print("you are ",age,"years old")
# Out:
# what is your name?ahmed
# how old are you?40
# hello ahmed
# you are  40 years old
